# %% [markdown]
# ### Garima Thakur
#
# GRIP : The Sparks Foundation
#
# Task 3: Performing Exploratory Data Analysis on Sample Superstore
#
# In this problem we will try to find out the weak areas where he can work to make more profit.

# %%
#Importing all the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading the data
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Check for the null values
print(df.isnull().sum())
sns.heatmap(df.isnull(), cbar = False)
plt.title("Null values")
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
# Text(0.5, 1.0, 'Null values')

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(np.round(df.corr(),2), cmap ="YlGnBu", linecolor='white', linewidths=1, annot = True )
plt.title('Correaltion between each parameter')
# Out:
# Text(0.5, 1.0, 'Correaltion between each parameter')

# %%
#Let's see which category dominates the market
print(df['Category'].value_counts())
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(df['Category'])
plt.ylabel("Purchase")
plt.subplot(1,2,2)
df['Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# From the above graph it's clear that office supplies got the maximum sales.

# %%
#Let's see which category dominates the market
df['Sub-Category'].value_counts()
plt.figure(figsize=(20,10), dpi = 80, facecolor='w', edgecolor='k')
sns.countplot(df['Sub-Category'], hue= df['Category'])
plt.figure(figsize=(18,8))
plt.bar('Sub-Category','Category', data = df, color = "yellow")
# Out:
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <BarContainer object of 9994 artists>

# %% [markdown]
# Binders and paper are clearly winning the game

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.countplot(df['Region'])
plt.subplot(2,2,2)
sns.countplot(df['Region'], hue= df['Category'])
# Out:
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
# plt.figure(figsize=(30,10), dpi = 80, facecolor='w', edgecolor='k')
# sns.countplot(df['State'])

plt.figure(figsize=(20,10), dpi = 80, facecolor='w', edgecolor='k')
sns.countplot(df['Sub-Category'], hue= df['Region'])
# Out:
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
Sales_per_State = df.groupby('State')
Sales_per_State.get_group('California')
# Sales_per_State
# for state, state_df in Sales_per_State:
#     print(state)
#     print(state_df)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 2       Second Class  Corporate  United States  Los Angeles  California
# 5     Standard Class   Consumer  United States  Los Angeles  California
# 6     Standard Class   Consumer  United States  Los Angeles  California
# 7     Standard Class   Consumer  United States  Los Angeles  California
# 8     Standard Class   Consumer  United States  Los Angeles  California
# ...              ...        ...            ...          ...         ...
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# ...

# %%
Sales_per_State.max()  ##here you are dividing your dataset in different groups and then you are running analytics on each of these groups
                        # and finding which city state has max profit by using max()
# Out:
#                            Ship Mode      Segment        Country  \
# State
# Alabama               Standard Class  Home Office  United States
# Arizona               Standard Class  Home Office  United States
# Arkansas              Standard Class  Home Office  United States
# California            Standard Class  Home Office  United States
# Colorado              Standard Class  Home Office  United States
# Connecticut           Standard Class  Home Office  United States
# Delaware              Standard Class  Home Office  United States
# District of Columbia  Standard Class  Home Office  United States
# Florida               Standard Class  Home Office  United States
# Georgia               Standard Class  Home Office  United States
# Idaho                 Standard Class  Home Office  United States
# Illinois              Standard Class  Home Office  United States
# Indiana               Standard Class  Home Office  United States
# ...

# %%
Sales_per_State.describe()
# Out:
#                      Postal Code                                               \
#                            count          mean          std      min      25%
# State
# Alabama                     61.0  35994.573770   490.770261  35244.0  35601.0
# Arizona                    224.0  85277.348214   244.753750  85023.0  85023.0
# Arkansas                    60.0  72321.816667   292.072344  71603.0  72209.0
# California                2001.0  92145.246877  1916.626492  90004.0  90045.0
# Colorado                   182.0  80295.758242   333.282713  80004.0  80027.0
# Connecticut                 82.0   6475.670732   291.845218   6010.0   6360.0
# Delaware                    96.0  19755.250000    62.869790  19711.0  19711.0
# District of Columbia        10.0  20016.000000     0.000000  20016.0  20016.0
# Florida                    383.0  33003.198433   565.282793  32114.0  32303.0
# Georgia                    184.0  30899.347826   804.960107  30062.0  30318.0
# ...

# %%
#Let's see which state gives the highest profit
plt.figure(figsize=(20,10), dpi = 80, facecolor='w', edgecolor='k')
df.groupby(['State'])['Profit'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'pink')
plt.title('State vs Profit')
# Out:
# Text(0.5, 1.0, 'State vs Profit')

# %%
plt.figure(figsize=(15,10), dpi = 80, facecolor='w', edgecolor='k')
df.groupby(['Sub-Category'])['Profit','Sales'].agg(sum).plot(kind = 'bar')
# Out:
# c:\users\garim\anaconda3\envs\tsf_new\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# From the above plot, we can see that there is more profit in copier but the sales of the phones and the chairs are higher.

# %% [markdown]
# Thank You!
